# %%
import datetime as dt
import time as tm

# %%
dtnow=dt.datetime.now()  # Get the current date and time
dtnow
# Out:
# datetime.datetime(2025, 12, 15, 14, 38, 6, 598970)

# %%
tm.time()  # Get the current time in seconds since the Epoch
# Out:
# 1765787939.8933766

# %%
delta=dt.timedelta(days=100)  # Create a timedelta of 100 days
delta
# Out:
# datetime.timedelta(days=100)

# %%
today = dt.date.today()  # Get today's date
today
# Out:
# datetime.date(2025, 12, 15)

# %%
today-delta  # Date 100 days ago
# Out:
# datetime.date(2025, 9, 6)

# %%
today>today-delta  # Is today after the date 100 days ago?
# Out:
# True
