# %%
import csv
# %precision 2 # Set floating point output precision

with open('mpg.csv') as csvfile: # Open the CSV file
    mpg=list(csv.DictReader(csvfile)) # Read the file into a list of dictionaries

mpg[:3]  # Display the first 3 records
# Out:
# [{'mpg': '18.0',
#   'cylinders': '8',
#   'displacement': '307.0',
#   'horsepower': '130.0',
#   'weight': '3504',
#   'acceleration': '12.0',
#   'model_year': '70',
#   'origin': 'usa',
#   'name': 'chevrolet chevelle malibu'},
#  {'mpg': '15.0',
#   'cylinders': '8',
#   'displacement': '350.0',
#   'horsepower': '165.0',
#   'weight': '3693',
#   'acceleration': '11.5',
#   'model_year': '70',
#   'origin': 'usa',
#   'name': 'buick skylark 320'},
#  {'mpg': '18.0',
#   'cylinders': '8',
#   'displacement': '318.0',
#   'horsepower': '150.0',
#   'weight': '3436',
#   'acceleration': '11.0',
#   'model_year': '70',
#   'origin': 'usa',
#   'name': 'plymouth satellite'}]

# %%
len(mpg)
# Out:
# 398

# %%
sum(float(i['cylinders']) for i in mpg) / len(mpg)  # Average number of cylinders
# Out:
# 5.454773869346734
