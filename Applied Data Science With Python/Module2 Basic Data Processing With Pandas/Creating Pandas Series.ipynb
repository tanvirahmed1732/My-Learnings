# %%
import pandas as pd
import numpy as np

# %%
student_scores={'Alice': 'Physics',
                'Jack': 'Maths',
                'Molly': 'Biology'}
s=pd.Series(student_scores)
s
# Out:
# Alice    Physics
# Jack       Maths
# Molly    Biology
# dtype: object

# %%
s.index #we can get the index of the series
# Out:
# Index(['Alice', 'Jack', 'Molly'], dtype='object')

# %%
s=pd.Series(['Physics', 'Maths', 'Biology'], index=['Alice', 'Jack', 'Molly']) #we can also specify the index while creating the series
s
# Out:
# Alice    Physics
# Jack       Maths
# Molly    Biology
# dtype: object

# %%
s=pd.Series(student_scores, index=['Molly', 'Jack', 'Bob']) #we can also specify a different index with exluding and including values
s
# Out:
# Molly    Biology
# Jack       Maths
# Bob          NaN
# dtype: object
