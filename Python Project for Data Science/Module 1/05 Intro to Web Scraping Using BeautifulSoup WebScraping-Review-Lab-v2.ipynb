# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="https://bso/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork23455606-2021-01-01">Beautiful Soup Object</a>
#             <ul>
#                 <li>Tag</li>
#                 <li>Children, Parents, and Siblings</li>
#                 <li>HTML Attributes</li>
#                 <li>Navigable String</li>
#             </ul>
#         </li>
#      </ul>
#     <ul>
#         <li>
#             <a href="https://filter/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork23455606-2021-01-01">Filter</a>
#             <ul>
#                 <li>find All</li>
#                 <li>find </li>
#                 <li>HTML Attributes</li>
#                 <li>Navigable String</li>
#             </ul>
#         </li>
#      </ul>
#      <ul>
#         <li>
#             <a href="https://dscw/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork23455606-2021-01-01">Downloading And Scraping The Contents Of A Web</a>
#     </li>
#          </ul>
#     <p>
#         Estimated time needed: <strong>25 min</strong>
#     </p>
#
# </div>
#
# <hr>

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
# !mamba install bs4==4.10.0 -y
# !pip install lxml==4.6.4
# !mamba install html5lib==1.1 -y
# !pip install pandas
# !pip install requests==2.26.0

# %% [markdown]
# Import the required modules and functions

# %%
pip install --upgrade beautifulsoup4

# %%
pip install --upgrade pandas

# %% [markdown]
# suppress all warnings

# %%
import warnings
warnings.simplefilter("ignore")

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %% [markdown]
# <h2 id="BSO">Beautiful Soup Objects</h2>

# %% [markdown]
# Beautiful Soup is a Python library for pulling data out of HTML and XML files, we will focus on HTML files. This is accomplished by representing the HTML as a set of objects with methods used to parse the HTML.  We can navigate the HTML as a tree and/or filter out what we are looking for.
#
# Consider the following HTML:

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>

# %% [markdown]
# We can store it as a string in the variable HTML:

# %%
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"

# %% [markdown]
# To parse a document, pass it into the <code>BeautifulSoup</code> constructor, the <code>BeautifulSoup</code> object, which represents the document as a nested data structure:

# %%
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# First, the document is converted to Unicode, (similar to ASCII),  and HTML entities are converted to Unicode characters. Beautiful Soup transforms a complex HTML document into a complex tree of Python objects. The <code>BeautifulSoup</code> object can create other types of objects. In this lab, we will cover <code>BeautifulSoup</code> and <code>Tag</code> objects that for the purposes of this lab are identical, and <code>NavigableString</code> objects.

# %% [markdown]
# We can use the method <code>prettify()</code> to display the HTML in the nested structure:

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>

# %% [markdown]
# ## Tags

# %% [markdown]
# Let's say we want the  title of the page and the name of the top paid player we can use the <code>Tag</code>. The <code>Tag</code> object corresponds to an HTML tag in the original document, for example, the tag title.

# %%
tag_object=soup.title
print("tag object:",tag_object)
# Out:
# tag object: <title>Page Title</title>

# %% [markdown]
# we can see the tag type <code>bs4.element.Tag</code>

# %%
print("tag object type:",type(tag_object))
# Out:
# tag object type: <class 'bs4.element.Tag'>

# %% [markdown]
# If there is more than one <code>Tag</code>  with the same name, the first element with that <code>Tag</code> name is called, this corresponds to the most paid player:

# %%
tag_object=soup.h3
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %% [markdown]
# Enclosed in the bold attribute <code>b</code>, it helps to use the tree representation. We can navigate down the tree using the child attribute to get the name.

# %% [markdown]
# ### Children, Parents, and Siblings

# %% [markdown]
# As stated above the <code>Tag</code> object is a tree of objects we can access the child of the tag or navigate down the branch as follows:

# %%
tag_child =tag_object.b
tag_child
# Out:
# <b id="boldest">Lebron James</b>

# %% [markdown]
# You can access the parent with the <code> parent</code>

# %%
parent_tag=tag_child.parent
parent_tag
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %% [markdown]
# this is identical to

# %%
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %% [markdown]
# <code>tag_object</code> parent is the <code>body</code> element.

# %%
tag_object.parent
# Out:
# <body><h3><b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body>

# %% [markdown]
# <code>tag_object</code> sibling is the <code>paragraph</code> element

# %%
sibling_1=tag_object.next_sibling
sibling_1
# Out:
# <p> Salary: $ 92,000,000 </p>

# %% [markdown]
# `sibling_2` is the `header` element which is also a sibling of both `sibling_1` and `tag_object`

# %%
sibling_2=sibling_1.next_sibling
sibling_2
# Out:
# <h3> Stephen Curry</h3>

# %% [markdown]
# <h3 id="first_question">Exercise: <code>next_sibling</code></h3>

# %% [markdown]
# Using the object <code>sibling\_2</code> and the property <code>next_sibling</code> to find the salary of Stephen Curry:

# %%
sibling_2.next_sibling
# Out:
# <p> Salary: $85,000, 000 </p>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```
# sibling_2.next_sibling
#
# ```
#
# </details>

# %% [markdown]
# ### HTML Attributes

# %% [markdown]
# If the tag has attributes, the tag <code>id="boldest"</code> has an attribute <code>id</code> whose value is <code>boldest</code>. You can access a tag’s attributes by treating the tag like a dictionary:

# %%
tag_child['id']
# Out:
# 'boldest'

# %% [markdown]
# You can access that dictionary directly as <code>attrs</code>:

# %%
tag_child.attrs
# Out:
# {'id': 'boldest'}

# %% [markdown]
# You can also work with Multi-valued attribute check out <a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork23455606-2021-01-01">\[1]</a> for more.

# %% [markdown]
# We can also obtain the content if the attribute of the <code>tag</code> using the Python <code>get()</code> method.

# %%
tag_child.get('id')
# Out:
# 'boldest'

# %% [markdown]
# ### Navigable String

# %% [markdown]
# A string corresponds to a bit of text or content within a tag. Beautiful Soup uses the <code>NavigableString</code> class to contain this text. In our HTML we can obtain the name of the first player by extracting the sting of the <code>Tag</code> object <code>tag_child</code> as follows:

# %%
tag_string=tag_child.string
tag_string
# Out:
# 'Lebron James'

# %% [markdown]
# we can verify the type is Navigable String

# %%
type(tag_string)
# Out:
# bs4.element.NavigableString

# %% [markdown]
# A NavigableString is just like a Python string or Unicode string, to be more precise. The main difference is that it also supports some  <code>BeautifulSoup</code> features. We can covert it to sting object in Python:

# %%
unicode_string = str(tag_string)
unicode_string
# Out:
# 'Lebron James'

# %% [markdown]
# <h2 id="filter">Filter</h2>

# %% [markdown]
# Filters allow you to find complex patterns, the simplest filter is a string. In this section we will pass a string to a different filter method and Beautiful Soup will perform a match against that exact string.  Consider the following HTML of rocket launchs:

# %%
# %%html
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# Out:
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>

# %% [markdown]
# We can store it as a string in the variable <code>table</code>:

# %%
table="<table><tr><td id='flight' >Flight No</td><td>Launch site</td><td>Payload mass</td></tr><tr><td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a> </td><td>80 kg</td></tr></table>"

# %%
table_bs = BeautifulSoup(table, "html.parser")

# %% [markdown]
# ## find All

# %% [markdown]
# The <code>find_all()</code> method looks through a tag’s descendants and retrieves all descendants that match your filters.
#
# <p>
# The Method signature for <code>find_all(name, attrs, recursive, string, limit, **kwargs)<c/ode>
# </p>

# %% [markdown]
# ### Name

# %% [markdown]
# When we set the <code>name</code> parameter to a tag name, the method will extract all the tags with that name and its children.

# %%
table_rows=table_bs.find_all('tr')
table_rows
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>,
#  <tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a> </td><td>80 kg</td></tr>]

# %% [markdown]
# The result is a Python Iterable just like a list, each element is a <code>tag</code> object:

# %%
first_row =table_rows[0]
first_row
# Out:
# <tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>

# %% [markdown]
# The type is <code>tag</code>

# %%
print(type(first_row))
# Out:
# <class 'bs4.element.Tag'>

# %% [markdown]
# we can obtain the child

# %%
first_row.td
# Out:
# <td id="flight">Flight No</td>

# %% [markdown]
# If we iterate through the list, each element corresponds to a row in the table:

# %%
for i,row in enumerate(table_rows):
    print("row",i,"is",row)
# Out:
# row 0 is <tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>
# row 1 is <tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr>
# row 2 is <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>
# row 3 is <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a> </td><td>80 kg</td></tr>

# %% [markdown]
# As <code>row</code> is a <code>cell</code> object, we can apply the method <code>find_all</code> to it and extract table cells in the object <code>cells</code> using the tag <code>td</code>, this is all the children with the name <code>td</code>. The result is a list, each element corresponds to a cell and is a <code>Tag</code> object, we can iterate through this list as well. We can extract the content using the <code>string</code>  attribute.

# %%
for i,row in enumerate(table_rows):
    print("row",i)
    cells=row.find_all('td')
    for j,cell in enumerate(cells):
        print('colunm',j,"cell",cell)
# Out:
# row 0
# colunm 0 cell <td id="flight">Flight No</td>
# colunm 1 cell <td>Launch site</td>
# colunm 2 cell <td>Payload mass</td>
# row 1
# colunm 0 cell <td>1</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td>
# colunm 2 cell <td>300 kg</td>
# row 2
# colunm 0 cell <td>2</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# colunm 2 cell <td>94 kg</td>
# row 3
# colunm 0 cell <td>3</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a> </td>
# colunm 2 cell <td>80 kg</td>

# %% [markdown]
# If we use a list we can match against any item in that list.

# %%
list_input=table_bs .find_all(name=["tr", "td"])
list_input
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td>,
#  <td>300 kg</td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a> </td><td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a> </td>,
#  <td>80 kg</td>]

# %% [markdown]
# ## Attributes

# %% [markdown]
# If the argument is not recognized it will be turned into a filter on the tag’s attributes. For example the <code>id</code>  argument, Beautiful Soup will filter against each tag’s <code>id</code> attribute. For example, the first <code>td</code> elements have a value of <code>id</code> of <code>flight</code>, therefore we can filter based on that <code>id</code> value.

# %%
table_bs.find_all(id="flight")
# Out:
# [<td id="flight">Flight No</td>]

# %% [markdown]
# We can find all the elements that have links to the Florida Wikipedia page:

# %%
list_input=table_bs.find_all(href="https://en.wikipedia.org/wiki/Florida")
list_input
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida</a>]

# %% [markdown]
# If we set the  <code>href</code> attribute to True, regardless of what the value is, the code finds all tags with <code>href</code> value:

# %%
table_bs.find_all(href=True)
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida</a>,
#  <a href="https://en.wikipedia.org/wiki/Texas">Texas</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida</a>]

# %% [markdown]
# There are other methods for dealing with attributes and other related methods; Check out the following <a href='https://www.crummy.com/software/BeautifulSoup/bs4/doc/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork23455606-2021-01-01#css-selectors'>link</a>

# %% [markdown]
# <h3 id="exer_type">Exercise: <code>find_all</code></h3>

# %% [markdown]
# Using the logic above, find all the elements without <code>href</code> value

# %%
table_bs.find_all('a', href=False)
# Out:
# []

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```
# table_bs.find_all('a', href=False)
#
# ```
#
# </details>

# %% [markdown]
# Using the soup object <code>soup</code>, find the element with the <code>id</code> attribute content set to <code>"boldest"</code>.

# %%
soup.find_all(id='boldest')
# Out:
# [<b id="boldest">Lebron James</b>]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```
# soup.find_all(id="boldest")
#
# ```
#
# </details>

# %% [markdown]
# ### string

# %% [markdown]
# With string you can search for strings instead of tags, where we find all the elments with Florida:

# %%
table_bs.find_all(string="Florida")
# Out:
# ['Florida', 'Florida']

# %% [markdown]
# ## find

# %% [markdown]
# The <code>find_all()</code> method scans the entire document looking for results, it’s if you are looking for one element you can use the <code>find()</code> method to find the first element in the document. Consider the following two table:

# %%
# %%html
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party  </h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>
# Out:
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party  </h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>

# %% [markdown]
# We store the HTML as a Python string and assign <code>two_tables</code>:

# %%
two_tables="<h3>Rocket Launch </h3><p><table class='rocket'><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table></p><p><h3>Pizza Party  </h3><table class='pizza'><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td >144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr>"

# %% [markdown]
# We create a <code>BeautifulSoup</code> object  <code>two_tables_bs</code>

# %%
two_tables_bs= BeautifulSoup(two_tables, 'html.parser')

# %% [markdown]
# We can find the first table using the tag name table

# %%
two_tables_bs.find("table")
# Out:
# <table class="rocket"><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table>

# %% [markdown]
# We can filter on the class attribute to find the second table, but because class is a keyword in Python, we add an underscore.

# %%
two_tables_bs.find("table",class_='pizza')
# Out:
# <table class="pizza"><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td>144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr></table>

# %% [markdown]
# <h2 id="DSCW">Downloading And Scraping The Contents Of A Web Page</h2>

# %% [markdown]
# We Download the contents of the web page:

# %%
url = "https://www.zazzle.com/dinosaur+birthday+invitations?st=orderitemcount_month"

# %% [markdown]
# We use <code>get</code> to download the contents of the webpage in text format and store in a variable called <code>data</code>:

# %%
data  = requests.get(url).text

# %% [markdown]
# We create a <code>BeautifulSoup</code> object using the <code>BeautifulSoup</code> constructor

# %%
soup = BeautifulSoup(data,"html.parser")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a',href=True):  # in html anchor/link is represented by the tag <a>

    print(link.get('href'))
# Out:
# https://www.zazzle.com/terms/user_agreement
# https://www.zazzle.com/terms/privacy_notice#cookies
# https://www.zazzle.com/events
# https://www.zazzle.com/zazzleplus
# https://www.zazzle.com/coupons
# https://www.zazzle.com/coupons
# https://www.zazzle.com/
# https://www.zazzle.com/sell
# https://www.zazzle.com/co/cart
# https://www.zazzle.com/s/dinosaur+birthday+invitations+for+kids?st=orderitemcount_month&dp=252888566444136039&q=dinosaur+birthday+invitations+for+kids&sgsc=dinosaur%3AFor+kids&gs=true
# https://www.zazzle.com/s/dinosaur+birthday+invitations+boy?st=orderitemcount_month&dp=252888566444136039&q=dinosaur+birthday+invitations+boy&sgsc=dinosaur%3ABoy&gs=true
# https://www.zazzle.com/s/dinosaur+birthday+invitations+girl?st=orderitemcount_month&dp=252888566444136039&q=dinosaur+birthday+invitations+girl&sgsc=dinosaur%3AGirl&gs=true
# https://www.zazzle.com/s/dinosaur+birthday+invitations+wild?st=orderitemcount_month&dp=252888566444136039&q=dinosaur+birthday+invitations+wild&sgsc=dinosaur%3AWild&gs=true
# https://www.zazzle.com/s/dinosaur+birthday+invitations+stomp+chomp+roar?st=orderitemcount_month&dp=252888566444136039&q=dinosaur+birthday+invitations+stomp+chomp+roar&sgsc=dinosaur%3AStomp+chomp+roar&gs=true
# https://www.zazzle.com/s/dinosaur+birthday+invitations+jurassic+animals?st=orderitemcount_month&dp=252888566444136039&q=dinosaur+birthday+invitations+jurassic+animals&sgsc=dinosaur%3AJurassic+animals&gs=true
# https://www.zazzle.com/s/dinosaur+birthday+invitations+rustic+greenery+leaves?st=orderitemcount_month&dp=252888566444136039&q=dinosaur+birthday+invitations+rustic+greenery+leaves&sgsc=dinosaur%3ARustic+greenery+leaves&gs=true
# https://www.zazzle.com/c/cards+stamps
# https://www.zazzle.com/c/invitations
# https://www.zazzle.com/c/birthday+invitations
# https://www.zazzle.com/custom/birthday+invitations
# https://www.zazzle.com/dinosaur_birthday_invitation_editable_three_rex_3_invitation-256239054852971253
# https://www.zazzle.com/dinosaur_birthday_invitation_editable_three_rex_3_invitation-256239054852971253
# https://www.zazzle.com/two_rex_cute_dinosaur_cartoon_2nd_birthday_party_invitation-256523785147308136
# https://www.zazzle.com/two_rex_cute_dinosaur_cartoon_2nd_birthday_party_invitation-256523785147308136
# https://www.zazzle.com/boys_green_stomp_chomp_roar_dinosaur_1st_birthday_invitation-256489287202226620
# https://www.zazzle.com/boys_green_stomp_chomp_roar_dinosaur_1st_birthday_invitation-256489287202226620
# https://www.zazzle.com/dinosaur_birthday_party_1st_birthday_first_birthda_invitation-256908369133459083
# https://www.zazzle.com/dinosaur_birthday_party_1st_birthday_first_birthda_invitation-256908369133459083
# https://www.zazzle.com/boys_cute_jungle_dinosaur_kids_5th_birthday_invitation-256868507008028880
# https://www.zazzle.com/boys_cute_jungle_dinosaur_kids_5th_birthday_invitation-256868507008028880
# https://www.zazzle.com/wild_three_dino_party_girl_pink_dinosaur_birthday_invitation-256338940313849482
# https://www.zazzle.com/dinosaur_pink_birthday_invitation_editable_three_3-256400296408448557
# https://www.zazzle.com/dinosaur_pink_birthday_invitation_editable_three_3-256400296408448557
# https://www.zazzle.com/girly_three_rex_dinosaur_birthday_invitation-256024014247354909
# https://www.zazzle.com/girly_three_rex_dinosaur_birthday_invitation-256024014247354909
# https://www.zazzle.com/dinosaur_third_birthday_invitation-256666456231158462
# https://www.zazzle.com/dinosaur_third_birthday_invitation-256666456231158462
# https://www.zazzle.com/three_rex_dinosaur_third_birthday_invitation-256177451812068657
# https://www.zazzle.com/three_rex_dinosaur_third_birthday_invitation-256177451812068657
# /dinosaur+birthday+invitations?st=orderitemcount_month
# /dinosaur+birthday+invitations?st=orderitemcount_month&pg=2
# /dinosaur+birthday+invitations?st=orderitemcount_month&pg=3
# /dinosaur+birthday+invitations?st=orderitemcount_month&pg=4
# /dinosaur+birthday+invitations?st=orderitemcount_month&pg=5
# /dinosaur+birthday+invitations?st=orderitemcount_month&pg=2
# https://www.zazzle.com/about
# https://www.zazzle.com/about/corporateresponsibility
# https://www.zazzle.com/about/press/releases
# https://www.zazzle.com/jobs
# https://www.zazzle.com/my/home
# https://www.zazzle.com/my/orders/history
# https://www.zazzle.com/returns
# https://www.zazzle.com/about/ask
# https://www.zazzle.com/sell
# https://www.zazzle.com/sell/affiliates
# https://www.zazzle.com/policy/community
# https://www.zazzle.com/ideas
# https://www.zazzle.com/events
# https://www.zazzle.com/sitemap
# https://www.facebook.com/zazzle
# https://instagram.com/zazzle
# https://www.pinterest.com/zazzle
# https://youtube.com/user/ZazzleTV
# https://www.tiktok.com/@zazzle
# https://itunes.apple.com/us/app/zazzle/id736836912
# https://play.google.com/store/apps/details?id=com.zazzle
# https://www.zazzle.com/terms/user_agreement
# https://www.zazzle.com/terms/privacy_notice
# https://www.zazzle.com/policy/community
# https://www.zazzle.com/about/accessibility

# %% [markdown]
# ## Scrape  all images  Tags

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link)
    print(link.get('src'))
# Out:
# <img alt="USA" class="Header2021RightContent_regionFlag" src="https://asset.zcache.com/assets/graphics/z4/brand_2016/header/flags/SVG/flag.zazzlecom.svg"/>
# https://asset.zcache.com/assets/graphics/z4/brand_2016/header/flags/SVG/flag.zazzlecom.svg
# <img alt="Search for dinosaur birthday invitations For kids" aria-hidden="true" class="VisualChipsRow_image" src="https://rlv.zcache.com/-r_dn9vd_130.jpg" srcset="https://rlv.zcache.com/-r_dn9vd_130.jpg 1x, https://rlv.zcache.com/-r_dn9vd_195.jpg 1.5x, https://rlv.zcache.com/-r_dn9vd_260.jpg 2x, https://rlv.zcache.com/-r_dn9vd_390.jpg 3x"/>
# https://rlv.zcache.com/-r_dn9vd_130.jpg
# <img alt="Search for dinosaur birthday invitations Rustic greenery leaves" aria-hidden="true" class="VisualChipsRow_image" src="https://rlv.zcache.com/-r0087faa4057a4b9594c60860c683bb4c_tcvt0_130.jpg" srcset="https://rlv.zcache.com/-r0087faa4057a4b9594c60860c683bb4c_tcvt0_130.jpg 1x, https://rlv.zcache.com/-r0087faa4057a4b9594c60860c683bb4c_tcvt0_195.jpg 1.5x, https://rlv.zcache.com/-r0087faa4057a4b9594c60860c683bb4c_tcvt0_260.jpg 2x, https://rlv.zcache.com/-r0087faa4057a4b9594c60860c683bb4c_tcvt0_390.jpg 3x"/>
# https://rlv.zcache.com/-r0087faa4057a4b9594c60860c683bb4c_tcvt0_130.jpg
# <img alt="Dinosaur Birthday Invitation, Editable Three Rex 3 Invitation" class="SearchResultsGridCellRealview-realview" sizes="(max-width: 667px) 306px, (max-width: 900px) 275px, (max-width: 1080px) 247px, 262px" src="https://rlv.zcache.com/dinosaur_birthday_invitation_editable_three_rex_3_invitation-r_jqt1tf_306.jpg" srcset="https://rlv.zcache.com/dinosaur_birthday_invitation_editable_three_rex_3_invitation-r_jqt1tf_247.jpg 247w, https://rlv.zcache.com/dinosaur_birthday_invitation_editable_three_rex_3_invitation-r_jqt1tf_494.jpg 494w, https://rlv.zcache.com/dinosaur_birthday_invitation_editable_three_rex_3_invitation-r_jqt1tf_612.jpg 612w"/>
# https://rlv.zcache.com/dinosaur_birthday_invitation_editable_three_rex_3_invitation-r_jqt1tf_306.jpg
# <img alt="Two-Rex Cute Dinosaur Cartoon 2nd Birthday Party Invitation" class="SearchResultsGridCellRealview-realview" sizes="(max-width: 667px) 306px, (max-width: 900px) 275px, (max-width: 1080px) 247px, 262px" src="https://rlv.zcache.com/two_rex_cute_dinosaur_cartoon_2nd_birthday_party_invitation-r_vs21t6_306.jpg" srcset="https://rlv.zcache.com/two_rex_cute_dinosaur_cartoon_2nd_birthday_party_invitation-r_vs21t6_247.jpg 247w, https://rlv.zcache.com/two_rex_cute_dinosaur_cartoon_2nd_birthday_party_invitation-r_vs21t6_494.jpg 494w, https://rlv.zcache.com/two_rex_cute_dinosaur_cartoon_2nd_birthday_party_invitation-r_vs21t6_612.jpg 612w"/>
# https://rlv.zcache.com/two_rex_cute_dinosaur_cartoon_2nd_birthday_party_invitation-r_vs21t6_306.jpg
# <img alt="Boys Green Stomp Chomp Roar Dinosaur 1st Birthday Invitation" class="SearchResultsGridCellRealview-realview" sizes="(max-width: 667px) 306px, (max-width: 900px) 275px, (max-width: 1080px) 247px, 262px" src="https://rlv.zcache.com/boys_green_stomp_chomp_roar_dinosaur_1st_birthday_invitation-r_zeeerz_306.jpg" srcset="https://rlv.zcache.com/boys_green_stomp_chomp_roar_dinosaur_1st_birthday_invitation-r_zeeerz_247.jpg 247w, https://rlv.zcache.com/boys_green_stomp_chomp_roar_dinosaur_1st_birthday_invitation-r_zeeerz_494.jpg 494w, https://rlv.zcache.com/boys_green_stomp_chomp_roar_dinosaur_1st_birthday_invitation-r_zeeerz_612.jpg 612w"/>
# https://rlv.zcache.com/boys_green_stomp_chomp_roar_dinosaur_1st_birthday_invitation-r_zeeerz_306.jpg
# <img alt="Dinosaur Birthday Party 1st Birthday First Birthda Invitation" class="SearchResultsGridCellRealview-realview" sizes="(max-width: 667px) 306px, (max-width: 900px) 275px, (max-width: 1080px) 247px, 262px" src="https://rlv.zcache.com/dinosaur_birthday_party_1st_birthday_first_birthda_invitation-r_jtrroo_306.jpg" srcset="https://rlv.zcache.com/dinosaur_birthday_party_1st_birthday_first_birthda_invitation-r_jtrroo_247.jpg 247w, https://rlv.zcache.com/dinosaur_birthday_party_1st_birthday_first_birthda_invitation-r_jtrroo_494.jpg 494w, https://rlv.zcache.com/dinosaur_birthday_party_1st_birthday_first_birthda_invitation-r_jtrroo_612.jpg 612w"/>
# https://rlv.zcache.com/dinosaur_birthday_party_1st_birthday_first_birthda_invitation-r_jtrroo_306.jpg
# <img alt="Boys Cute Jungle Dinosaur Kids 5th Birthday Invitation" class="SearchResultsGridCellRealview-realview" sizes="(max-width: 667px) 306px, (max-width: 900px) 275px, (max-width: 1080px) 247px, 262px" src="https://rlv.zcache.com/boys_cute_jungle_dinosaur_kids_5th_birthday_invitation-r_zqnksv_306.jpg" srcset="https://rlv.zcache.com/boys_cute_jungle_dinosaur_kids_5th_birthday_invitation-r_zqnksv_247.jpg 247w, https://rlv.zcache.com/boys_cute_jungle_dinosaur_kids_5th_birthday_invitation-r_zqnksv_494.jpg 494w, https://rlv.zcache.com/boys_cute_jungle_dinosaur_kids_5th_birthday_invitation-r_zqnksv_612.jpg 612w"/>
# https://rlv.zcache.com/boys_cute_jungle_dinosaur_kids_5th_birthday_invitation-r_zqnksv_306.jpg
# <img alt="Roar Into Four Pink Dinosaur 4th Birthday Party Invitation" class="SearchResultsGridCellRealview-realview" sizes="(max-width: 667px) 306px, (max-width: 900px) 275px, (max-width: 1080px) 247px, 262px" src="https://rlv.zcache.com/roar_into_four_pink_dinosaur_4th_birthday_party_invitation-r_v0603e_306.jpg" srcset="https://rlv.zcache.com/roar_into_four_pink_dinosaur_4th_birthday_party_invitation-r_v0603e_247.jpg 247w, https://rlv.zcache.com/roar_into_four_pink_dinosaur_4th_birthday_party_invitation-r_v0603e_494.jpg 494w, https://rlv.zcache.com/roar_into_four_pink_dinosaur_4th_birthday_party_invitation-r_v0603e_612.jpg 612w"/>
# https://rlv.zcache.com/roar_into_four_pink_dinosaur_4th_birthday_party_invitation-r_v0603e_306.jpg
# <img alt="Two-Rex Dinosaur Birthday Invitation" class="SearchResultsGridCellRealview-realview" sizes="(max-width: 667px) 306px, (max-width: 900px) 275px, (max-width: 1080px) 247px, 262px" src="https://rlv.zcache.com/two_rex_dinosaur_birthday_invitation-r_wccsq0_306.jpg" srcset="https://rlv.zcache.com/two_rex_dinosaur_birthday_invitation-r_wccsq0_247.jpg 247w, https://rlv.zcache.com/two_rex_dinosaur_birthday_invitation-r_wccsq0_494.jpg 494w, https://rlv.zcache.com/two_rex_dinosaur_birthday_invitation-r_wccsq0_612.jpg 612w"/>
# https://rlv.zcache.com/two_rex_dinosaur_birthday_invitation-r_wccsq0_306.jpg
# <img alt="Dinosaur Three-Rex Boy's 3rd Birthday Party Invitation" class="SearchResultsGridCellRealview-realview" sizes="(max-width: 667px) 306px, (max-width: 900px) 275px, (max-width: 1080px) 247px, 262px" src="https://rlv.zcache.com/dinosaur_three_rex_boys_3rd_birthday_party_invitation-r_wsa6hc_306.jpg" srcset="https://rlv.zcache.com/dinosaur_three_rex_boys_3rd_birthday_party_invitation-r_wsa6hc_247.jpg 247w, https://rlv.zcache.com/dinosaur_three_rex_boys_3rd_birthday_party_invitation-r_wsa6hc_494.jpg 494w, https://rlv.zcache.com/dinosaur_three_rex_boys_3rd_birthday_party_invitation-r_wsa6hc_612.jpg 612w"/>
# https://rlv.zcache.com/dinosaur_three_rex_boys_3rd_birthday_party_invitation-r_wsa6hc_306.jpg
# <img alt="Dinosaur Three Rex 3rd Birthday Party Invitation" class="SearchResultsGridCellRealview-realview" sizes="(max-width: 667px) 306px, (max-width: 900px) 275px, (max-width: 1080px) 247px, 262px" src="https://rlv.zcache.com/dinosaur_three_rex_3rd_birthday_party_invitation-r_w5r1tf_306.jpg" srcset="https://rlv.zcache.com/dinosaur_three_rex_3rd_birthday_party_invitation-r_w5r1tf_247.jpg 247w, https://rlv.zcache.com/dinosaur_three_rex_3rd_birthday_party_invitation-r_w5r1tf_494.jpg 494w, https://rlv.zcache.com/dinosaur_three_rex_3rd_birthday_party_invitation-r_w5r1tf_612.jpg 612w"/>
# https://rlv.zcache.com/dinosaur_three_rex_3rd_birthday_party_invitation-r_w5r1tf_306.jpg
# <img alt="" aria-hidden="true" class="SiteCultureSelector2_flagIcon" src="https://asset.zcache.com/assets/graphics/z4/brand_2016/header/flags/SVG/flag.zazzlecom.svg"/>
# https://asset.zcache.com/assets/graphics/z4/brand_2016/header/flags/SVG/flag.zazzlecom.svg

# %% [markdown]
# ## Scrape data from HTML tables

# %%
#The below url contains an html table with data about colors and color codes.
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a web site, you need to examine the contents, and the way data is organized on the website. Open the above url in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html.parser")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %%
#Get all rows from the table
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].string # store the value in column 3 as color_name
    color_code = cols[3].string # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->None
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %% [markdown]
# ## Scrape data from HTML tables into a DataFrame using BeautifulSoup and Pandas

# %%
import pandas as pd

# %%
#The below url contains html tables with data about world population.
url = "https://en.wikipedia.org/wiki/World_population"

# %% [markdown]
# Before proceeding to scrape a web site, you need to examine the contents, and the way data is organized on the website. Open the above url in your browser and check the tables on the webpage.

# %%
# get the contents of the webpage in text format and store in a variable called data
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/91.0.4472.124 Safari/537.36"
}

data  = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(data.text,"html.parser")

# %%
#find all html tables in the web page
tables = soup.find_all('table') # in html table is represented by the tag <table>

# %%
# we can see how many tables were found by checking the length of the tables list
len(tables)
# Out:
# 26

# %% [markdown]
# Assume that we are looking for the `10 most densly populated countries` table, we can look through the tables list and find the right one we are look for based on the data in each table or we can search for the table name if it is in the table but this option might not always work.

# %%
for index,table in enumerate(tables):
    if ("10 most densely populated countries" in str(table)):
        table_index = index
print(table_index)
# Out:
# 5

# %% [markdown]
# See if you can locate the table name of the table, `10 most densly populated countries`, below.

# %%
print(tables[table_index].prettify())
# Out:
# <table class="wikitable sortable" style="text-align:right">
#  <caption>
#   10 most densely populated countries
#   <small>
#    (with population above 5 million)
#   </small>
#   <sup class="reference" id="cite_ref-:10_106-0">
#    <a href="#cite_note-:10-106">
#     <span class="cite-bracket">
#      [
#     </span>
#     101
#     <span class="cite-bracket">
#      ]
#     </span>
#    </a>
#   </sup>
#  </caption>
#  <tbody>
#   <tr>
#    <th scope="col">
#     Rank
#    </th>
#    <th scope="col">
#     Country
#    </th>
#    <th scope="col">
#     Population
#    </th>
#    <th scope="col">
#     Area
#     <br/>
#     <small>
#      (km
#      <sup>
#       2
#      </sup>
#      )
#     </small>
#    </th>
#    <th scope="col">
#     Density
#     <br/>
#     <small>
#      (pop/km
#      <sup>
#       2
#      </sup>
#      )
#     </small>
#    </th>
#   </tr>
#   <tr>
#    <td>
#     1
#    </td>
#    <td align="left">
#     <span class="flagicon nowrap">
#      <span class="mw-image-border" typeof="mw:File">
#       <span>
#        <img alt="" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/48/Flag_of_Singapore.svg/40px-Flag_of_Singapore.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/48/Flag_of_Singapore.svg/60px-Flag_of_Singapore.svg.png 2x" width="23"/>
#       </span>
#      </span>
#     </span>
#     <a href="/wiki/Singapore" title="Singapore">
#      Singapore
#     </a>
#    </td>
#    <td>
#     5,921,231
#    </td>
#    <td>
#     719
#    </td>
#    <td>
#     8,235
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2
#    </td>
#    <td align="left">
#     <span class="flagicon nowrap">
#      <span class="mw-image-border" typeof="mw:File">
#       <span>
#        <img alt="" class="mw-file-element" data-file-height="307" data-file-width="512" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/40px-Flag_of_Bangladesh.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/60px-Flag_of_Bangladesh.svg.png 2x" width="23"/>
#       </span>
#      </span>
#     </span>
#     <a href="/wiki/Bangladesh" title="Bangladesh">
#      Bangladesh
#     </a>
#    </td>
#    <td>
#     165,650,475
#    </td>
#    <td>
#     148,460
#    </td>
#    <td>
#     1,116
#    </td>
#   </tr>
#   <tr>
#    <td>
#     3
#    </td>
#    <td align="left">
#     <p>
#      <span class="flagicon nowrap">
#       <span class="mw-image-border" typeof="mw:File">
#        <span>
#         <img alt="" class="mw-file-element" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Flag_of_Palestine.svg/40px-Flag_of_Palestine.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Flag_of_Palestine.svg/60px-Flag_of_Palestine.svg.png 2x" width="23"/>
#        </span>
#       </span>
#      </span>
#      <a href="/wiki/Palestine" title="Palestine">
#       Palestine
#      </a>
#      <sup class="reference" id="cite_ref-107">
#       <a href="#cite_note-107">
#        <span class="cite-bracket">
#         [
#        </span>
#        note 3
#        <span class="cite-bracket">
#         ]
#        </span>
#       </a>
#      </sup>
#      <sup class="reference" id="cite_ref-108">
#       <a href="#cite_note-108">
#        <span class="cite-bracket">
#         [
#        </span>
#        102
#        <span class="cite-bracket">
#         ]
#        </span>
#       </a>
#      </sup>
#     </p>
#    </td>
#    <td>
#     5,223,000
#    </td>
#    <td>
#     6,025
#    </td>
#    <td>
#     867
#    </td>
#   </tr>
#   <tr>
#    <td>
#     4
#    </td>
#    <td align="left">
#     <span class="flagicon nowrap">
#      <span class="mw-image-border" typeof="mw:File">
#       <span>
#        <img alt="" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/40px-Flag_of_the_Republic_of_China.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/60px-Flag_of_the_Republic_of_China.svg.png 2x" width="23"/>
#       </span>
#      </span>
#     </span>
#     <a href="/wiki/Taiwan" title="Taiwan">
#      Taiwan
#     </a>
#     <sup class="reference" id="cite_ref-109">
#      <a href="#cite_note-109">
#       <span class="cite-bracket">
#        [
#       </span>
#       note 4
#       <span class="cite-bracket">
#        ]
#       </span>
#      </a>
#     </sup>
#    </td>
#    <td>
#     23,580,712
#    </td>
#    <td>
#     35,980
#    </td>
#    <td>
#     655
#    </td>
#   </tr>
#   <tr>
#    <td>
#     5
#    </td>
#    <td align="left">
#     <span class="flagicon nowrap">
#      <span class="mw-image-border" typeof="mw:File">
#       <span>
#        <img alt="" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/40px-Flag_of_South_Korea.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/60px-Flag_of_South_Korea.svg.png 2x" width="23"/>
#       </span>
#      </span>
#     </span>
#     <a href="/wiki/South_Korea" title="South Korea">
#      South Korea
#     </a>
#    </td>
#    <td>
#     51,844,834
#    </td>
#    <td>
#     99,720
#    </td>
#    <td>
#     520
#    </td>
#   </tr>
#   <tr>
#    <td>
#     6
#    </td>
#    <td align="left">
#     <span class="flagicon nowrap">
#      <span class="mw-image-border" typeof="mw:File">
#       <span>
#        <img alt="" class="mw-file-element" data-file-height="1920" data-file-width="2880" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Flag_of_Lebanon.svg/40px-Flag_of_Lebanon.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Flag_of_Lebanon.svg/60px-Flag_of_Lebanon.svg.png 2x" width="23"/>
#       </span>
#      </span>
#     </span>
#     <a href="/wiki/Lebanon" title="Lebanon">
#      Lebanon
#     </a>
#    </td>
#    <td>
#     5,296,814
#    </td>
#    <td>
#     10,400
#    </td>
#    <td>
#     509
#    </td>
#   </tr>
#   <tr>
#    <td>
#     7
#    </td>
#    <td align="left">
#     <span class="flagicon nowrap">
#      <span class="mw-image-border" typeof="mw:File">
#       <span>
#        <img alt="" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/17/Flag_of_Rwanda.svg/40px-Flag_of_Rwanda.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/17/Flag_of_Rwanda.svg/60px-Flag_of_Rwanda.svg.png 2x" width="23"/>
#       </span>
#      </span>
#     </span>
#     <a href="/wiki/Rwanda" title="Rwanda">
#      Rwanda
#     </a>
#    </td>
#    <td>
#     13,173,730
#    </td>
#    <td>
#     26,338
#    </td>
#    <td>
#     500
#    </td>
#   </tr>
#   <tr>
#    <td>
#     8
#    </td>
#    <td align="left">
#     <span class="flagicon nowrap">
#      <span class="mw-image-border" typeof="mw:File">
#       <span>
#        <img alt="" class="mw-file-element" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/50/Flag_of_Burundi.svg/40px-Flag_of_Burundi.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/50/Flag_of_Burundi.svg/60px-Flag_of_Burundi.svg.png 2x" width="23"/>
#       </span>
#      </span>
#     </span>
#     <a href="/wiki/Burundi" title="Burundi">
#      Burundi
#     </a>
#    </td>
#    <td>
#     12,696,478
#    </td>
#    <td>
#     27,830
#    </td>
#    <td>
#     456
#    </td>
#   </tr>
#   <tr>
#    <td>
#     9
#    </td>
#    <td align="left">
#     <span class="flagicon nowrap">
#      <span class="mw-image-border" typeof="mw:File">
#       <span>
#        <img alt="" class="mw-file-element" data-file-height="800" data-file-width="1100" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Israel.svg/40px-Flag_of_Israel.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Israel.svg/60px-Flag_of_Israel.svg.png 2x" width="21"/>
#       </span>
#      </span>
#     </span>
#     <a href="/wiki/Israel" title="Israel">
#      Israel
#     </a>
#    </td>
#    <td>
#     9,402,617
#    </td>
#    <td>
#     21,937
#    </td>
#    <td>
#     429
#    </td>
#   </tr>
#   <tr>
#    <td>
#     10
#    </td>
#    <td align="left">
#     <span class="flagicon nowrap">
#      <span class="mw-image-border" typeof="mw:File">
#       <span>
#        <img alt="" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/40px-Flag_of_India.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/60px-Flag_of_India.svg.png 2x" width="23"/>
#       </span>
#      </span>
#     </span>
#     <a href="/wiki/India" title="India">
#      India
#     </a>
#    </td>
#    <td>
#     1,389,637,446
#    </td>
#    <td>
#     3,287,263
#    </td>
#    <td>
#     423
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
population_data = pd.DataFrame(columns=["Rank", "Country", "Population", "Area", "Density"])

for row in tables[table_index].tbody.find_all("tr"):
    col = row.find_all("td")
    if col:
        rank = col[0].text.strip()
        country = col[1].text.strip()
        population = col[2].text.strip()
        area = col[3].text.strip()
        density = col[4].text.strip()

        # Create a temporary DataFrame for the new row
        new_row = pd.DataFrame([{"Rank": rank, "Country": country, "Population": population, "Area": area, "Density": density}])

        # Use concat 
        population_data = pd.concat([population_data, new_row], ignore_index=True)

population_data
# Out:
#   Rank                 Country     Population       Area Density
# 0    1               Singapore      5,921,231        719   8,235
# 1    2              Bangladesh    165,650,475    148,460   1,116
# 2    3  Palestine[note 3][102]      5,223,000      6,025     867
# 3    4          Taiwan[note 4]     23,580,712     35,980     655
# 4    5             South Korea     51,844,834     99,720     520
# 5    6                 Lebanon      5,296,814     10,400     509
# 6    7                  Rwanda     13,173,730     26,338     500
# 7    8                 Burundi     12,696,478     27,830     456
# 8    9                  Israel      9,402,617     21,937     429
# 9   10                   India  1,389,637,446  3,287,263     423

# %% [markdown]
# ## Scrape data from HTML tables into a DataFrame using BeautifulSoup and read_html

# %% [markdown]
# Using the same `url`, `data`, `soup`, and `tables` object as in the last section we can use the `read_html` function to create a DataFrame.
#
# Remember the table we need is located in `tables[table_index]`
#
# We can now use the `pandas` function `read_html` and give it the string version of the table as well as the `flavor` which is the parsing engine `bs4`.

# %%
pd.read_html(str(tables[5]), flavor='bs4')
# Out:
# [   Rank                 Country  Population  Area (km2)  Density (pop/km2)
#  0     1               Singapore     5921231         719               8235
#  1     2              Bangladesh   165650475      148460               1116
#  2     3  Palestine[note 3][102]     5223000        6025                867
#  3     4          Taiwan[note 4]    23580712       35980                655
#  4     5             South Korea    51844834       99720                520
#  5     6                 Lebanon     5296814       10400                509
#  6     7                  Rwanda    13173730       26338                500
#  7     8                 Burundi    12696478       27830                456
#  8     9                  Israel     9402617       21937                429
#  9    10                   India  1389637446     3287263                423]

# %% [markdown]
# The function `read_html` always returns a list of DataFrames so we must pick the one we want out of the list.

# %%
population_data_read_html = pd.read_html(str(tables[5]), flavor='bs4')[0]

population_data_read_html
# Out:
#    Rank                 Country  Population  Area (km2)  Density (pop/km2)
# 0     1               Singapore     5921231         719               8235
# 1     2              Bangladesh   165650475      148460               1116
# 2     3  Palestine[note 3][102]     5223000        6025                867
# 3     4          Taiwan[note 4]    23580712       35980                655
# 4     5             South Korea    51844834       99720                520
# 5     6                 Lebanon     5296814       10400                509
# 6     7                  Rwanda    13173730       26338                500
# 7     8                 Burundi    12696478       27830                456
# 8     9                  Israel     9402617       21937                429
# 9    10                   India  1389637446     3287263                423

# %% [markdown]
# ## Scrape data from HTML tables into a DataFrame using read_html

# %% [markdown]
# We can also use the `read_html` function to directly get DataFrames from a `url`.

# %%
dataframe_list = pd.read_html(data.text, flavor='bs4')

# %% [markdown]
# We can see there are 25 DataFrames just like when we used `find_all` on the `soup` object.

# %%
len(dataframe_list)
# Out:
# 26

# %% [markdown]
# Finally we can pick the DataFrame we need out of the list.

# %%
dataframe_list[5]
# Out:
#    Rank                 Country  Population  Area (km2)  Density (pop/km2)
# 0     1               Singapore     5921231         719               8235
# 1     2              Bangladesh   165650475      148460               1116
# 2     3  Palestine[note 3][102]     5223000        6025                867
# 3     4          Taiwan[note 4]    23580712       35980                655
# 4     5             South Korea    51844834       99720                520
# 5     6                 Lebanon     5296814       10400                509
# 6     7                  Rwanda    13173730       26338                500
# 7     8                 Burundi    12696478       27830                456
# 8     9                  Israel     9402617       21937                429
# 9    10                   India  1389637446     3287263                423

# %% [markdown]
# We can also use the `match` parameter to select the specific table we want. If the table contains a string matching the text it will be read.

# %%
heading = soup.find("h3", {"id": "Most_densely_populated_countries"})

# Get the next table after this heading
table = heading.find_next("table")

# Convert to DataFrame
df = pd.read_html(str(table))[0]
print(df.head())
# Out:
#    Rank                 Country  Population  Area (km2)  Density (pop/km2)
# 0     1               Singapore     5921231         719               8235
# 1     2              Bangladesh   165650475      148460               1116
# 2     3  Palestine[note 3][102]     5223000        6025                867
# 3     4          Taiwan[note 4]    23580712       35980                655
# 4     5             South Korea    51844834       99720                520

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# <!-- ## Change Log
# | Date (YYYY-MM-DD) | Version | Changed By                                               | Change Description |
# | ----------------- | ------- | -------------------------------------------------------- | ------------------ |
# | 2021-08-04        | 0.2     | Made changes to markdown of nextsibling                  |                    |
# | 2020-10-17        | 0.1     | Joseph Santarcangelo  Created initial version of the lab |                    |
# --!>

# %% [markdown]
# ####  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork23455606-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork-19487395&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
