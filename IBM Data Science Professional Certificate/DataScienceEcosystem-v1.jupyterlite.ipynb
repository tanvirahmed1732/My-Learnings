# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# ## Instructions
#
# Complete the exercises below by creating the appropriate Markdown or Code cells as specified. Add your content or code in the corresponding cells.
#
# > **Note: Insert the required cells directly below each exercise before adding your answer.**

# %% [markdown]
# #### Exercise 1: Create a markdown cell with title of the notebook
#
# Create a markdown cell with the title <span style="color:red">  Data Science Tools and Ecosystem</span> using <span style="color:red">H1 </span> style heading.

# %% [markdown]
# <h1>Data Science Tools and Ecosystem</h1>

# %% [markdown]
# #### Exercise 2 - Create a markdown cell for an introduction
#
# Write an introductory sentence about the notebook such as the follows:
#
# <span style="color:red">In this notebook, Data Science Tools and Ecosystem are summarized.<span>

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# #### Exercise 3 - Create a markdown cell to list data science languages
#
# Start the cell with an overview line such as:
#
# <span style="color:red">Some of the popular languages that Data Scientists use are:</span>
#
# Then create an <span style="color:red">ordered list</span> (i.e. numbered) listing 3 (or more) commonly used languages for data science.

# %% [markdown]
# <h3>Some of the popular languages that Data Scientists use are:</h3>
# <ol>
#     <li>Python</li>
#     <li>R</li>
#     <li>SQL</li>
#     <li>Julia</li>
#     <li>Scala</li>
# </ol>

# %% [markdown]
# #### Exercise 4 - Create a markdown cell to list data science libraries
#
# Add an overview line to the cell like:
#
# <span style="color:red">Some of the commonly used libraries used by Data Scientists include:</span>
#
# Below this line add an <span style="color:red">ordered list</span> listing 3 (or more) commonly used libraries in data science.

# %% [markdown]
# <h3>Some of the commonly used libraries used by Data Scientists include:</h3>
# <ol>
#     <li>Pandas</li>
#     <li>NumPy</li>
#     <li>Matplotlib</li>
#     <li>Scikit-learn</li>
#     <li>TensorFlow</li>
# </ol>

# %% [markdown]
# #### Exercise 5 - Create a markdown cell with a table of Data Science tools
#
# Create a single column table in this cell with the first row containing the header <span style="color:red">Data Science Tools</span>.
# The subsequent three rows in the table should indicate three development environment open source tools used in data science.
#
#
# _Hint: Refer to Lab: Using Markdowns in Jupyter Notebooks to create a table._

# %% [markdown]
# <table>
#     <tr>
#         <th>Data Science Tools</th>
#     </tr>
#     <tr>
#         <td>Jupyter Notebook</td>
#     </tr>
#     <tr>
#         <td>RStudio</td>
#     </tr>
#     <tr>
#         <td>Apache Spark</td>
#     </tr>
# </table>

# %% [markdown]
# #### Exercise 6 - Create a markdown cell introducing arithmetic expression examples
#
# Add a line in this cell with H3 style heading with text like:
#
# <span style="color:red">Below are a few examples of evaluating arithmetic expressions in Python.</span>

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python.</h3>
#
# ```python
# # Example 1: basic arithmetic
# 2 + 3 * 4
#
# # Example 2: parentheses and division
# (10 - 2) / 4
#
# # Example 3: power and modulus
# 3 ** 2 % 4
# ```

# %% [markdown]
# #### Exercise 7 - Create a code cell to multiply and add numbers
#
# In this code cell evaluate the expression <span style="color:red">(3*4)+5.</span>
#
# Insert a comment line before the expression to explain the operation e.g.  <span style="color:red">This a simple arithmetic expression to mutiply then add integers.</span>
#
# Then execute the cell to ensure the expression returns the expected output of <span style="color:red">17</span>.

# %%
#This a simple arithmetic expression to multiply then add intergers
(3*4)+5
# Out:
# 17

# %% [markdown]
# #### Exercise 8 - Create a code cell to convert minutes to hours
#
# In this code cell write an expression that converts <span style="color:red">200 minutes into <span style="color:red">hours.
#
# Insert a comment line before the expression to explain the operation e.g.  <span style="color:red">This will convert 200 minutes to hours by diving by 60.
#
# Run the cell to evaluate the expression.

# %%
#This will convert 200 mintes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# #### Exercise 9 - Insert a markdown cell to list Objectives
#
# Below the introduction cell created in Exercise 2, insert a new markdown cell to list the objectives that this notebook covered (i.e. some of the key takeaways from the course).
# In this new cell start with an introductory line titled: <span style="color:red">Objectives:</span> in bold font. Then using an <span style="color:red">unordered list</span> (bullets) indicate 3 to 5 items covered in this notebook, such as <span style="color:red">List popular languages for Data Science</span>

# %% [markdown]
# **Objectives:**
# <ul>
# <li> List popular languages for Data Science </li>
# <li> Identify common data science tools and development environments </li>
# <li> Understand basic data science workflows and tasks </li>
# <li> Practice simple Python examples for arithmetic evaluation</li>
# </ul>

# %% [markdown]
# #### Exercise 10 - Create a markdown cell to indicate the Author's name
#
# In this cell include the following text <span style="color:red">Author</span> in <span style="color:red">H2 style heading</span>. Include your <span style="color:red">name</span> as regular text below the word <span style="color:red">Author</span>.

# %% [markdown]
# <h2>Author</h2>
# Tanvir Ahmed

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
